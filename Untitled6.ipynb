# %%
import wfdb

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
header = wfdb.rdheader('/content/drive/MyDrive/holter/75713209')

# %%
record = wfdb.rdrecord('/content/drive/MyDrive/holter/75713209')

# %%
wfdb.plot.plot_all_records('/content/drive/MyDrive/holter/')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-ce0d1d07944b> in <cell line: 1>()
# ----> 1 wfdb.plot .plot_all_records('/content/drive/MyDrive/holter/')
#
# /usr/local/lib/python3.10/dist-packages/wfdb/plot/plot.py in plot_all_records(directory)
#    1197
#    1198         plot_wfdb(record, title="Record - %s" % record.record_name)
# -> 1199         input("Press enter to continue...")
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
wfdb.wfdb_to_edf('/content/drive/MyDrive/holter/75713209')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-f4f080eeb287> in <cell line: 1>()
# ----> 1 wfdb.wfdb_to_edf('/content/drive/MyDrive/holter/75713209')
#
# AttributeError: module 'wfdb' has no attribute 'wfdb_to_edf'

# %%
raw_record = record.to_dataframe()

# %%
raw_record.iloc[:, 0].transpose()
# Out:
# 2024-01-25 18:04:54.000   -0.22
# 2024-01-25 18:04:54.008   -0.08
# 2024-01-25 18:04:54.016   -0.20
# 2024-01-25 18:04:54.024   -0.30
# 2024-01-25 18:04:54.032   -0.38
#                            ...
# 2024-01-26 13:03:53.960    0.00
# 2024-01-26 13:03:53.968    0.02
# 2024-01-26 13:03:53.976    0.00
# 2024-01-26 13:03:53.984    0.00
# 2024-01-26 13:03:53.992    0.00
# Freq: 8L, Name: MARS export, Length: 8542500, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(raw_record.iloc[:, 0].transpose())

# %%
raw_record.iloc[:, 0].transpose().to_csv('/content/drive/MyDrive/holter/output.csv')

# %%
import pandas as pd

# %%
raw_record.to_xml('/content/drive/MyDrive/holter/output.xml')
# Out:
# <ipython-input-39-618c903a4f6d>:1: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   raw_record.to_xml('/content/drive/MyDrive/holter/output.xml')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-618c903a4f6d> in <cell line: 1>()
# ----> 1 raw_record.to_xml('/content/drive/MyDrive/holter/output.xml')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_xml(self, path_or_buffer, index, root_name, row_name, na_rep, attr_cols, elem_cols, namespaces, prefix, encoding, xml_declaration, pretty_print, parser, stylesheet, compression, storage_options)
#    3429         )
#    3430
# -> 3431         return xml_formatter.write_output()
#    3432
#    3433     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/xml.py in write_output(self)
# ...

# %%
# !ls /content/drive/MyDrive/holter/
# Out:
# 75713209.hea  76738016.hea  81346394.hea  81385508.hea	output.csv
# 75713209.SIG  76738016.SIG  81346394.SIG  81385508.SIG

# %%
header.sig_name
# Out:
# ['MARS export', 'MARS export', 'MARS export']

# %%
raw_record
# Out:
#                          MARS export  MARS export  MARS export
# 2024-01-25 18:04:54.000        -0.22         0.02         0.00
# 2024-01-25 18:04:54.008        -0.08         0.02         0.02
# 2024-01-25 18:04:54.016        -0.20        -0.02        -0.10
# 2024-01-25 18:04:54.024        -0.30        -0.12        -0.16
# 2024-01-25 18:04:54.032        -0.38        -0.20        -0.14
# ...                              ...          ...          ...
# 2024-01-26 13:03:53.960         0.00         0.00         0.00
# 2024-01-26 13:03:53.968         0.02         0.00         0.00
# 2024-01-26 13:03:53.976         0.00         0.00         0.00
# 2024-01-26 13:03:53.984         0.00         0.00         0.00
# 2024-01-26 13:03:53.992         0.00         0.00         0.00
#
# [8542500 rows x 3 columns]
